# %%
# !pip install auto-sklearn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 6.5 MB 9.5 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 260 kB 40.3 MB/s
# ...
#      |████████████████████████████████| 4.4 MB 60.1 MB/s
# ...
#      |████████████████████████████████| 4.9 MB 48.8 MB/s
# ...
#      |████████████████████████████████| 24.9 MB 1.7 MB/s
# ...
#      |████████████████████████████████| 46 kB 4.1 MB/s
# ...
#   Created wheel for auto-sklearn: filename=auto_sklearn-0.15.0-py3-none-any.whl size=6641945 sha256=abe0bebef92ee75d33b4f4402d1fa1d9a24621726e4ea045114e7745c7c7d949
#   Stored in directory: /root/.cache/pip/wheels/c5/11/0e/aeac2cee929fa4388e528737b49deb2eea05486e6f80d61c1a
# ...

# %%
import pandas as pd 
import numpy as np
import torch
from torch import nn
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import autosklearn.classification

# %%
train = pd.read_csv("train.csv")
train.head()
# Out:
#    RowNumber  CustomerId     Surname  CreditScore Geography  Gender  Age  \
# 0        551    15806307   Trevisano          720     Spain    Male   38
# 1       6897    15709621      Martin          682    France  Female   54
# 2       4588    15619340      Palmer          672    France  Female   31
# 3        291    15620746  Napolitani          592     Spain  Female   40
# 4       1673    15646372         Yao          753     Spain    Male   42
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       5  114051.97              2          0               1
# 1       4   62397.41              1          1               0
# 2       5  119903.67              1          1               1
# 3       4  104257.86              1          1               0
# 4       5  120387.73              1          0               1
#
#    EstimatedSalary  Exited
# 0        107577.29       0
# 1        113088.60       1
# 2        132925.17       0
# 3        110857.33       0
# ...

# %%
df = train.drop(["RowNumber", "CustomerId", "Surname"], axis = 1)#deleting irrelevant feature
X = df.drop("Exited", axis = 1)
y = df["Exited"]

# %%
automl = autosklearn.classification.AutoSklearnClassifier( #defining automl classifier
    time_left_for_this_task = 180, #total time allowed
    per_run_time_limit = 30 #time allowed for each algorithm
)

automl.fit(X, y)
# Out:
# /usr/local/lib/python3.8/dist-packages/autosklearn/data/feature_validator.py:318: UserWarning: Input Column Geography has generic type object. Autosklearn will treat this column as string. Please ensure that this setting is suitable for your task.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/autosklearn/data/feature_validator.py:318: UserWarning: Input Column Gender has generic type object. Autosklearn will treat this column as string. Please ensure that this setting is suitable for your task.
#   warnings.warn(
# AutoSklearnClassifier(ensemble_class=<class 'autosklearn.ensembles.ensemble_selection.EnsembleSelection'>,
#                       per_run_time_limit=30, time_left_for_this_task=180)

# %%
automl.leaderboard()
# Out:
#           rank  ensemble_weight               type      cost  duration
# model_id
# 6            1             0.64  gradient_boosting  0.139015  3.471295
# 2            2             0.30      random_forest  0.142803  6.488528
# 12           3             0.06  gradient_boosting  0.151136  3.752519

# %%
automl.leaderboard(detailed = True)#this show the detail ranking & feature processing
#automl has become an integrated model
# Out:
#           rank  ensemble_weight               type      cost   duration  \
# model_id
# 6            1             0.22  gradient_boosting  0.139015   4.112163
# 2            2             0.30      random_forest  0.142803   6.330797
# 11           3             0.04      random_forest  0.145455  31.028859
# 10           4             0.26        extra_trees  0.150758  23.478786
# 5            5             0.18                sgd  0.198106   1.326188
#
#           config_id  train_loss  seed    start_time      end_time  budget  \
# model_id
# 6                 5    0.105784     0  1.670831e+09  1.670831e+09     0.0
# 2                 1    0.000000     0  1.670831e+09  1.670831e+09     0.0
# 11               10    0.059328     0  1.670831e+09  1.670831e+09     0.0
# 10                9    0.055597     0  1.670831e+09  1.670831e+09     0.0
# 5                 4    0.201119     0  1.670831e+09  1.670831e+09     0.0
#
# ...

# %%
test = pd.read_csv("test.csv")
test
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 0          2209    15623595        Scott          726    France  Female   39
# 1          9924    15740283     Yegorova          661    France    Male   42
# 2          4617    15802368          Tan          545    France    Male   34
# 3          6077    15615322  Anayochukwu          731     Spain  Female   42
# 4          9240    15766374       Glover          533    France  Female   50
# ...         ...         ...          ...          ...       ...     ...  ...
# 1995       7872    15617348       Taylor          628    France    Male   35
# 1996       4257    15642785     Tokareva          639   Germany    Male   41
# 1997       2273    15766575     Trevisan          548    France  Female   46
# 1998        315    15610271      Dickson          602     Spain  Female   44
# 1999       3628    15763895           He          615   Germany  Female   32
#
# ...

# %%
X_test = test.drop(["RowNumber", "CustomerId", "Surname"], axis = 1)
X_test
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             726    France  Female   39       3   62397.41              1
# 1             661    France    Male   42       3  130339.64              1
# 2             545    France    Male   34       6   62397.41              2
# 3             731     Spain  Female   42       3   86717.08              1
# 4             533    France  Female   50       6   62397.41              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 1995          628    France    Male   35       6   62397.41              2
# 1996          639   Germany    Male   41       5   98154.30              2
# 1997          548    France  Female   46       3  119078.34              2
# 1998          602     Spain  Female   44       7   62397.41              2
# 1999          615   Germany  Female   32       5  105570.37              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary
# ...

# %%
y_test = automl.predict(X_test)
y_test
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
upload = pd.read_csv("upload.csv")
upload
# Out:
#       Unnamed: 0  RowNumber  Exited
# 0              0       2209       0
# 1              1       9924       0
# 2              2       4617       0
# 3              3       6077       0
# 4              4       9240       0
# ...          ...        ...     ...
# 1995        1995       7872       0
# 1996        1996       4257       0
# 1997        1997       2273       0
# 1998        1998        315       0
# 1999        1999       3628       0
#
# [2000 rows x 3 columns]

# %%
upload["Exited"] = y_test
upload
# Out:
#       Unnamed: 0  RowNumber  Exited
# 0              0       2209       0
# 1              1       9924       0
# 2              2       4617       0
# 3              3       6077       0
# 4              4       9240       1
# ...          ...        ...     ...
# 1995        1995       7872       0
# 1996        1996       4257       0
# 1997        1997       2273       0
# 1998        1998        315       0
# 1999        1999       3628       0
#
# [2000 rows x 3 columns]

# %%
upload.to_csv("upload_automl.csv")
